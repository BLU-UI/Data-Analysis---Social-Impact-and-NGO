# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import CVS files
pd = pd.read_excel('Non Profit Transition.xlsx')

# %%
pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630 entries, 0 to 629
# Data columns (total 30 columns):
# Design ID                        630 non-null object
# Type of organization             630 non-null object
# Main source of funding           630 non-null object
# Product/service offering         630 non-null object
# In house/out of house            630 non-null object
# Business Monetization            630 non-null object
# Type of organization.1           630 non-null float64
# Main source of funding.1         630 non-null float64
# Product/service offering.1       630 non-null float64
# In house/out of house .1         630 non-null float64
# Business Monetization Phase      630 non-null float64
# Effectiveness                    630 non-null float64
# Type of organization.2           630 non-null float64
# Main source of funding.2         630 non-null float64
# Product/service offering.2       630 non-null int64
# In house/out of house .2         630 non-null int64
# ...

# %%
sns.relplot(x="Effectiveness", y="Cost", sizes=(40, 400), alpha=.5, palette="muted",height=6,data=pd)

# %%
#Scatter Plot based on orginazation to differieniate Non Profit, For Profit & Hybrid
sns.relplot(x="Effectiveness", y="Cost", hue="Type of organization", s=300,
           sizes=(100, 400), alpha=.5, palette="muted", height=6, data=pd)
